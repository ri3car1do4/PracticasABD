# %% [markdown]
# Este examen de prueba está diseñado para que probéis a arrancar todos los servidores de Bases de Datos, configurar el proyecto y la entrega de cara al examen. Os recomiendo **MUY** encarecidamente que probéis a hacerlo al menos una vez en los laboratorios de la facultad.

# %% [markdown]
# # Ejercicio 1 PostgreSQL
#
# Dada la tabla `cartas` en el archivo `cartas.csv`, crea una clase `GestionCartas` para gestionar el acceso a la base de datos. Debe implementar las siguientes operaciones:
#
# ## 1.1 Diccionario
#
# Crea una función que devuelva un diccionario que relacione cada nombre de carta con la lista de URLs de mkm que tiene asociadas. Nótese que hay varios nombres de cartas repetidas, así que la lista puede contener más de un elemento.
#
# Esquema: **nombre_carta:List[url]**
#
# ```python
# def nombre_carta2url(self) -> Dict[str, List[str]]
# ```

# %% [markdown]
# # Ejercicio 2 MongoDB
#
# Dada la colección `ventas` en el archivo `ventas.json`, crea una clase `GestionVentas` para gestionar el acceso a la base de datos. Debe implementar las siguientes operaciones:
#
# ## 2.1 Contar Documentos
#
# Crea una función que devuelva de documentos totales en la colección.
#
# Esquema: **numero_documentos**
#
# ```python
# def cuenta_documentos(self) -> int:
# ```

# %% [markdown]
# # Ejercicio 3 Neo4j
#
# Dada la base de datos que se genera desde el archivo `pole.dump`, crea una clase `GestionPole` para gestionar el acceso a la base de datos. Debe implementar las siguientes operaciones:

# %% [markdown]
# ## 3.1 Determinar Número de Personas
#
# Crea una función que devuelva el número total de personas en la base de datos.
#
# Esquema: **numero_personas**
#
# ```python
# def cuenta_personas(self) -> int:
# ```

# %% [markdown]
# # Ejercicio 4 Normalización
#
# La siguiente tabla modela qué empleados con la información de sus departamentos. Tenemos las siguientes restricciones:
#
# 1. Todos los empleados de un departamento están vinculados a un mismo edificio.
# 2. Cada empleado está identificado inequívocamente por su id, pero no por su nombre.
#
# Hemos propuesto el siguiente modelo relacional para representar nuestro sistema.
#
# * en_dep(ID, nombre, sueldo, nombre_dpto, edificio, presupuesto)
#
# Se os pide los siguientes apartados:
#
# 1. Computa las dependencias funcionales de la tabla.
# 2. Determina las claves candidatas de la tabla.
# 3. Indica si la tabla está en BCNF o no. Si no lo está, propón una descomposición en subtablas que preserve la información y cumpla esta forma normal. No es necesario justificar la respuesta en cada caso.

# %% [markdown]
# # Entrega

# %% [markdown]
# Para la entrega, comprime en un archivo `.zip` los 3 archivos `.py` de cada ejercicio y el archivo de texto con las respuestas sobre normalización: `ejercicio1.py`, `ejercicio2.py`, `ejercicio3.py` y `normalizacion.txt`. El nombre del archivo `.zip` debe incluir tu nombre y apellidos. Incluye en la primera línea de cada archivo de la solución un comentario con tu nombre y apellidos.
